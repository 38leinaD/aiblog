// %% [markdown]
// # Using Java in Jupyter

// %% [markdown]
// Installation of the [IJava](https://github.com/SpencerPark/IJava) kernel was very simple.
// Steps:

// %% [markdown]
// ```
// curl -LO https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip
// unzip -d ijava ijava-1.3.0.zip
// cd ijava
// python install.py --sys-prefix
// jupyter kernelspec list which
// ```

// %% [markdown]
// Or from source:

// %% [markdown]
// ```
// git clone https://github.com/frankfliu/IJava.git
// cd IJava/
// ./gradlew installKernel
// ```

// %% [markdown]
// Now i can start jupyter lab as normal and start a Java notebook. As an example, I can run below code.

// %%
%maven org.knowm.xchart:xchart:3.5.2

import org.knowm.xchart.*;
import org.knowm.xchart.style.colors.*;
import java.awt.Color;

double[] xData = new double[] { 0.0, 1.0, 2.0 };
double[] yData = new double[] { 2.0, 1.0, 0.0 };
XYChart chart = QuickChart.getChart("Sample Chart", "X", "Y", "y(x)", xData, yData);
chart.getStyler().setChartBackgroundColor(Color.WHITE);

BitmapEncoder.getBufferedImage(chart);
// Out:
// BufferedImage@f6a9fe2: type = 1 DirectColorModel: rmask=ff0000 gmask=ff00 bmask=ff amask=0 IntegerInterleavedRaster: width = 600 height = 400 #Bands = 3 xOff = 0 yOff = 0 dataOffset[0] 0
